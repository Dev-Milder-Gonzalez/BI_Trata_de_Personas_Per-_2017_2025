# %% [markdown]
# # Inteligencia de Negocios - Trata de Personas Perú 2017-2025🚓

# %% [markdown]
# ## 1. Importación de las principales librerías📚

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

#Configuramos la presentación de dato en Pandas
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.expand_frame_repr", False)
pd.set_option('display.max_colwidth', None) # Evitar que Pandas corte el contenido de las celdas

# %% [markdown]
# ## 2. Exploración de rápida de datos⚡

# %%
df_raw = pd.read_excel("../data/raw/DataSet_trata_personas_enero2017_septiembre2025.xlsx", sheet_name= "BD_CONSOLIDADO_TRATA")
print(f'DataSet cargado (cantidad de filas): {df_raw.shape[0]:,}')
# Out:
# DataSet cargado (cantidad de filas): 75,508

# %%
print(f'Datos del año 2017 del mes de Enero para el departamento de Ancash:\n{df_raw.head(86)}')
# Out:
# Datos del año 2017 del mes de Enero para el departamento de Ancash:
#      AÑO  MES  CCDD   lugar PROVINCIA  DISTRITO           COMISARÍA                       categoría                  Denuncias por comisión  Valor
# 0   2017    1     2  ÁNCASH     SANTA  CHIMBOTE  DIVICAJ -DEPINTRAP                       CAPTACIÓN                              C_INTERNET 0.0000
# 1   2017    1     2  ÁNCASH     SANTA  CHIMBOTE  DIVICAJ -DEPINTRAP                       CAPTACIÓN                     C_OFERTA DE ESTUDIO 0.0000
# 2   2017    1     2  ÁNCASH     SANTA  CHIMBOTE  DIVICAJ -DEPINTRAP                       CAPTACIÓN                     C_OFERTA DE TRABAJO 2.0000
# 3   2017    1     2  ÁNCASH     SANTA  CHIMBOTE  DIVICAJ -DEPINTRAP                       CAPTACIÓN                    C_OTRO (ESPECIFICAR) 0.0000
# 4   2017    1     2  ÁNCASH     SANTA  CHIMBOTE  DIVICAJ -DEPINTRAP                       CAPTACIÓN                            C_PADRINAZGO 0.0000
# ...

# %%
print(f'Las diez últimas filas (ver si no hay dato de resumen):\n{df_raw.tail(10)}')
# Out:
# Las diez últimas filas (ver si no hay dato de resumen):
#         AÑO  MES  CCDD  lugar PROVINCIA DISTRITO COMISARÍA                categoría Denuncias por comisión  Valor
# 75498  2025    9    23  TACNA       NaN      NaN       NaN  VÍNCULO CON EL TRATANTE               P4_TOTAL 1.0000
# 75499  2025    9    23  TACNA       NaN      NaN       NaN  VÍNCULO CON EL TRATANTE               P4_TUTOR 0.0000
# 75500  2025    9    23  TACNA       NaN      NaN       NaN     PERSONA QUE DENUNCIA                P5_OTRO 0.0000
# 75501  2025    9    23  TACNA       NaN      NaN       NaN     PERSONA QUE DENUNCIA             P5_HERMANA 0.0000
# 75502  2025    9    23  TACNA       NaN      NaN       NaN     PERSONA QUE DENUNCIA         P5_UN FAMILIAR 0.0000
# 75503  2025    9    23  TACNA       NaN      NaN       NaN     PERSONA QUE DENUNCIA               P5_MADRE 1.0000
# 75504  2025    9    23  TACNA       NaN      NaN       NaN     PERSONA QUE DENUNCIA               P5_TOTAL 1.0000
# ...

# %%
print(df_raw.sample(10))
# Out:
#         AÑO  MES  CCDD          lugar      PROVINCIA                                        DISTRITO                           COMISARÍA                       categoría            Denuncias por comisión   Valor
# 1616   2017    2    10        HUÁNUCO  LEONCIO PRADO                                     TINGO MARIA                         TINGO MARIA       INSTRUCCIÓN DE LA VÍCTIMA                          P3_TOTAL  1.0000
# 7523   2017    8    21           PUNO      SAN ROMÁN                                         JULIACA                   JULIACA-DEPINTRAP                     EXPLOTACIÓN                    F2_ALBAÑILERIA  0.0000
# 38506  2020   10    15           LIMA           LIMA                                            LIMA               DIRCTPTIM-EL AGUSTINO  MEDIO EMPLEADO POR EL TRATANTE                           M_TOTAL 32.0000
# ...

# %%
# Conteo de valores nulos por columna
null_counts = df_raw.isna().sum()
print(f"Valores nulos por columna:\n{null_counts}")
# Out:
# Valores nulos por columna:
# AÑO                           0
# MES                           0
# CCDD                          0
# lugar                         0
# PROVINCIA                 18146
# DISTRITO                  19006
# COMISARÍA                 18920
# categoría                     0
# Denuncias por comisión        0
# Valor                      1032
# dtype: int64

# %%
#Porcentajes nulos
null_percent = ( df_raw.isna().sum() / df_raw.shape[0] * 100).round(2)
print(f'Porcentaje de nulos por columnas:\n{null_percent}')
# Out:
# Porcentaje de nulos por columnas:
# AÑO                       0.0000
# MES                       0.0000
# CCDD                      0.0000
# lugar                     0.0000
# PROVINCIA                24.0300
# DISTRITO                 25.1700
# COMISARÍA                25.0600
# categoría                 0.0000
# Denuncias por comisión    0.0000
# Valor                     1.3700
# dtype: float64

# %%
#Columnas del dataset
print(f'Columnas originales del datset:\n{df_raw.columns.to_list()}')
# Out:
# Columnas originales del datset:
# ['AÑO', 'MES', 'CCDD', 'lugar', 'PROVINCIA', 'DISTRITO', 'COMISARÍA', 'categoría', 'Denuncias por comisión', 'Valor']

# %%
print(f'Información sobre el DataSet:\n{df_raw.info()}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75508 entries, 0 to 75507
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   AÑO                     75508 non-null  int64
#  1   MES                     75508 non-null  int64
#  2   CCDD                    75508 non-null  int64
#  3   lugar                   75508 non-null  object
#  4   PROVINCIA               57362 non-null  object
#  5   DISTRITO                56502 non-null  object
#  6   COMISARÍA               56588 non-null  object
#  7   categoría               75508 non-null  object
#  8   Denuncias por comisión  75508 non-null  object
#  9   Valor                   74476 non-null  float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 5.8+ MB
# Información sobre el DataSet:
# None
