# %% [markdown]
# # Análisis General – Series Anuales📈

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Configuración presetnación de datos
pd.set_option("display.max_columns", None) # Mostrar todas las columnas
pd.set_option("display.max_rows", None) # Mostrar más filas
pd.set_option("display.width", None) # Evita saltos de lineas raros
pd.set_option("display.float_format", lambda x: f'{x:,.4f}') #Formato de número
pd.set_option("display.expand_frame_repr", False)

# %% [markdown]
# ## 1. Cargamos el DatSet Maestro✅

# %%
df_wide = pd.read_excel("../data/processed/dataset_maestro_wide.xlsx")
print(f'✅DataSet maestro cargado')
print(f'Dimensiones: {df_wide.shape}')
# Out:
# ✅DataSet maestro cargado
# Dimensiones: (878, 95)

# %% [markdown]
# ## 2. Series de explotación📈

# %% [markdown]
# ### 2.1. Serie de tiempo anual

# %%
anual_explotacion = df_wide.groupby("AÑO")["EXPLOTACION_F2_TOTAL"].sum()
print(type(anual_explotacion))
print('-' * 70)
print(f'Explotación anual desde Enero 217 hasta Septiembre 2025, Perú:\n{anual_explotacion}')
# Out:
# <class 'pandas.core.series.Series'>
# ----------------------------------------------------------------------
# Explotación anual desde Enero 217 hasta Septiembre 2025, Perú:
# AÑO
# 2017    552
# 2018    378
# 2019    281
# 2020    372
# 2021    535
# 2022    631
# 2023    583
# 2024    669
# 2025    384
# Name: EXPLOTACION_F2_TOTAL, dtype: int64

# %%
sns.lineplot(x = anual_explotacion.index, y = anual_explotacion, marker = "o",color = "red")
for i, v in enumerate(anual_explotacion):
    #Anadir valores sobre cada punto
    plt.text(anual_explotacion.index[i], v, str(int(v)), ha = "center")

#Título del gráfico
plt.title("Explotación anual desde Enero 217 hasta Septiembre 2025, Perú")
plt.xlabel("Año")
plt.ylabel("Casos totales")
plt.grid(True)
plt.tight_layout()
plt.savefig("../reports/imagenes/Víctimas_de_explotación_por_año.png", dpi = 500)
plt.show()

# %% [markdown]
# ### 2.2. Serie de tiempo por año y mes

# %%
explotacion_anio_mes = df_wide.groupby("AÑO_MES")["EXPLOTACION_F2_TOTAL"].sum()
print(f"Explotación por año y mes desde Enero 217 hasta Septiembre 2025, Perú:\n{explotacion_anio_mes}")
# Out:
# Explotación por año y mes desde Enero 217 hasta Septiembre 2025, Perú:
# AÑO_MES
# 2017-01     71
# 2017-02     53
# 2017-03     42
# 2017-04     72
# 2017-05     50
# 2017-06     66
# 2017-07     37
# 2017-08     28
# 2017-09     26
# 2017-10     35
# 2017-11     30
# 2017-12     42
# 2018-01     30
# 2018-02     29
# 2018-03     22
# 2018-04     28
# 2018-05     23
# 2018-06     34
# 2018-07     30
# 2018-08     22
# 2018-09     35
# 2018-10     23
# 2018-11     45
# 2018-12     57
# 2019-01     44
# 2019-02     50
# 2019-03     23
# 2019-04      2
# 2019-05      7
# 2019-06     16
# 2019-07     23
# 2019-08     13
# 2019-09     37
# 2019-10     37
# 2019-11     27
# 2019-12      2
# 2020-01     51
# 2020-02     58
# 2020-03     31
# 2020-04      9
# 2020-05     13
# 2020-06     19
# 2020-07     27
# 2020-08     13
# 2020-09     45
# 2020-10     50
# 2020-11     45
# 2020-12     11
# 2021-01     53
# 2021-02     21
# 2021-03     41
# 2021-04     43
# 2021-05     34
# 2021-06     87
# 2021-07     54
# 2021-08     66
# 2021-09     31
# 2021-10     16
# 2021-11     16
# 2021-12     73
# 2022-01     52
# 2022-02     21
# 2022-03     25
# 2022-04     65
# 2022-05     83
# 2022-06     69
# 2022-07     27
# 2022-08    128
# 2022-09     25
# 2022-10     58
# 2022-11     26
# 2022-12     52
# 2023-01    583
# 2024-01     64
# 2024-02     51
# 2024-03     53
# 2024-04     58
# 2024-05     78
# 2024-06     58
# 2024-07     48
# 2024-08     57
# 2024-09     51
# 2024-10     72
# 2024-11     47
# 2024-12     32
# 2025-01     16
# 2025-02    113
# 2025-03     84
# 2025-04     33
# 2025-05     70
# 2025-06     25
# 2025-07     22
# 2025-08     11
# 2025-09     10
# Name: EXPLOTACION_F2_TOTAL, dtype: int64

# %%
plt.figure(figsize=(22, 7))

sns.lineplot(x=explotacion_anio_mes.index, 
             y=explotacion_anio_mes.values, 
             color="red", 
             marker="o")

for x, y in zip(explotacion_anio_mes.index, explotacion_anio_mes.values):
    plt.text(x, y, str(int(y)), ha='center', fontsize=8)

plt.title("Explotación por año y mes desde Enero 2017 hasta Septiembre 2025, Perú")
plt.xlabel("Año-mes")
plt.ylabel("Casos")
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.savefig("../reports/imagenes/Víctimas_de_explotación_por_año_mes.png", dpi = 800)
plt.show()

# %% [markdown]
# ## 3. Serie anual de explotación sexual📶

# %% [markdown]
# ### 3.1. Serie de tiempo por año

# %%
anual_explotacion_sexual = df_wide.groupby("AÑO")["FINALIDAD_DEL_TIPO_DE_DELITO_F1_EXPLOTACION_SEXUAL"].sum()
print(f'Explotación sexual anual desde Enero 2017 hasta Septiembre del 2025:\n{anual_explotacion_sexual}')
# Out:
# Explotación sexual anual desde Enero 2017 hasta Septiembre del 2025:
# AÑO
# 2017    400
# 2018    504
# 2019    335
# 2020    223
# 2021    327
# 2022    331
# 2023    308
# 2024    280
# 2025    169
# Name: FINALIDAD_DEL_TIPO_DE_DELITO_F1_EXPLOTACION_SEXUAL, dtype: int64

# %%
sns.lineplot(x = anual_explotacion_sexual.index, y = anual_explotacion_sexual, color = "#79aeb1", marker="o")
for i, v in enumerate(anual_explotacion_sexual):
    plt.text(anual_explotacion_sexual.index[i], v, str(int(v)), ha = "center")

plt.title("Explotación sexual anual desde Enero 2017 hasta Septiembre del 2025")
plt.xlabel("Año")
plt.ylabel("Total de casos")
plt.tight_layout()
plt.grid(True)
plt.savefig("../reports/imagenes/Víctimas_explotación_sexual_por_año.png", dpi = 500)
plt.show()

# %% [markdown]
# ### 3.2. Serie de tiempo por año y mes

# %%
explotacion_sexual_anio_mes = df_wide.groupby("AÑO_MES")["FINALIDAD_DEL_TIPO_DE_DELITO_F1_EXPLOTACION_SEXUAL"].sum()
print(f'Víctimas de explotación sexual desde Enero del 2017 hasta Septiembre del 2025 por año y mes: {explotacion_sexual_anio_mes}')
# Out:
# Víctimas de explotación sexual desde Enero del 2017 hasta Septiembre del 2025 por año y mes: AÑO_MES
# 2017-01     42
# 2017-02     27
# 2017-03     51
# 2017-04     49
# 2017-05     24
# 2017-06     32
# 2017-07     39
# 2017-08     35
# 2017-09     17
# 2017-10     32
# 2017-11     36
# 2017-12     16
# 2018-01     40
# 2018-02     32
# 2018-03     44
# 2018-04     44
# 2018-05     33
# 2018-06     69
# 2018-07     61
# 2018-08     26
# 2018-09     35
# 2018-10     33
# 2018-11     23
# 2018-12     64
# 2019-01     28
# 2019-02     56
# 2019-03     22
# 2019-04     28
# 2019-05      3
# 2019-06     11
# 2019-07     22
# 2019-08     22
# 2019-09     34
# 2019-10     20
# 2019-11     39
# 2019-12     50
# 2020-01     31
# 2020-02     37
# 2020-03     19
# 2020-04      7
# 2020-05     13
# 2020-06      9
# 2020-07     17
# 2020-08     11
# 2020-09     35
# 2020-10     32
# 2020-11      7
# 2020-12      5
# 2021-01     16
# 2021-02     11
# 2021-03     37
# 2021-04     32
# 2021-05     32
# 2021-06     20
# 2021-07     37
# 2021-08     40
# 2021-09     15
# 2021-10     10
# 2021-11     11
# 2021-12     66
# 2022-01     33
# 2022-02      8
# 2022-03      7
# 2022-04     48
# 2022-05     13
# 2022-06     61
# 2022-07     10
# 2022-08     56
# 2022-09     11
# 2022-10     48
# 2022-11      4
# 2022-12     32
# 2023-01    308
# 2024-01     22
# 2024-02     24
# 2024-03     24
# 2024-04     22
# 2024-05     31
# 2024-06     26
# 2024-07     13
# 2024-08     29
# 2024-09     25
# 2024-10     35
# 2024-11     18
# 2024-12     11
# 2025-01      5
# 2025-02     95
# 2025-03     27
# 2025-04     10
# 2025-05     11
# 2025-06      9
# 2025-07      3
# 2025-08      7
# 2025-09      2
# Name: FINALIDAD_DEL_TIPO_DE_DELITO_F1_EXPLOTACION_SEXUAL, dtype: int64

# %%
plt.figure(figsize=(22, 7))
sns.lineplot(
    x=explotacion_sexual_anio_mes.index,
    y=explotacion_sexual_anio_mes.values,
    color = "#79aeb1",
    marker = "o"
    )

for x, y in zip(explotacion_sexual_anio_mes.index, explotacion_sexual_anio_mes.values):
    plt.text(x, y, str(int(y)), ha="center", fontsize=8)
    
plt.title("Víctimas de explotación sexual desde Enero del 2017 hasta Septiembre del 2025 por año y mes")
plt.xlabel("Año_Mes")
plt.ylabel("Casos")
plt.xticks(rotation = 90)
plt. grid()
plt.tight_layout()
plt.savefig("../reports/imagenes/Víctimas_de_explotación_sexual_por_año_mes.png", dpi = 800)
plt.show()

# %% [markdown]
# ## 4. Menores de edad víctimas🧒

# %% [markdown]
# ### 4.1. Serie de tiempo anual

# %%
anual_menos_edad = df_wide.groupby("AÑO")["MENORES_18"].sum()
print(f'Menores de edad que son víctima del delito de trata de personas:\n{anual_menos_edad}')
# Out:
# Menores de edad que son víctima del delito de trata de personas:
# AÑO
# 2017      0
# 2018    136
# 2019     54
# 2020     50
# 2021    129
# 2022    103
# 2023     69
# 2024     76
# 2025     31
# Name: MENORES_18, dtype: int64

# %%
sns.lineplot(x=anual_menos_edad.index, y=anual_menos_edad, color = "red")
for i, v in enumerate(anual_menos_edad):
    plt.text(anual_menos_edad.index[i], v, str(int(v)))

plt.title("Menores de edad víctimas del delito de trata de personas al año")
plt.xlabel("Año")
plt.ylabel("Total de casos")
plt.grid(True)
plt.savefig("../reports/imagenes/Menores_de_edad_víctimas_trata_personas_por_año.png", dpi = 500)
plt.show()

# %% [markdown]
# ### 4.2. Serie de tiempo por año y mes

# %%
menores_edad_anio_mes = df_wide.groupby("AÑO_MES")["MENORES_18"].sum()
print(f"Menores de edad víctima del delito de trata de personas desde Enero 2017 hasta Septiembre del 2025:\n{menores_edad_anio_mes}")
# Out:
# Menores de edad víctima del delito de trata de personas desde Enero 2017 hasta Septiembre del 2025:
# AÑO_MES
# 2017-01     0
# 2017-02     0
# 2017-03     0
# 2017-04     0
# 2017-05     0
# 2017-06     0
# 2017-07     0
# 2017-08     0
# 2017-09     0
# 2017-10     0
# 2017-11     0
# 2017-12     0
# 2018-01    40
# 2018-02    22
# 2018-03    11
# 2018-04    11
# 2018-05     2
# 2018-06    15
# 2018-07     2
# 2018-08     6
# 2018-09    12
# 2018-10     1
# 2018-11     6
# 2018-12     8
# 2019-01     6
# 2019-02     2
# 2019-03     0
# 2019-04     3
# 2019-05     5
# 2019-06     6
# 2019-07     5
# 2019-08     0
# 2019-09     7
# 2019-10     1
# 2019-11     8
# 2019-12    11
# 2020-01     3
# 2020-02     7
# 2020-03     9
# 2020-04     2
# 2020-05     0
# 2020-06     3
# 2020-07     2
# 2020-08     4
# 2020-09    11
# 2020-10     1
# 2020-11     8
# 2020-12     0
# 2021-01    12
# 2021-02     1
# 2021-03     5
# 2021-04     6
# 2021-05     8
# 2021-06    27
# 2021-07    19
# 2021-08    15
# 2021-09     7
# 2021-10     5
# 2021-11     7
# 2021-12    17
# 2022-01    10
# 2022-02     4
# 2022-03     1
# 2022-04     3
# 2022-05    27
# 2022-06    11
# 2022-07     4
# 2022-08     9
# 2022-09     3
# 2022-10    20
# 2022-11     5
# 2022-12     6
# 2023-01    69
# 2024-01     6
# 2024-02     4
# 2024-03     5
# 2024-04     0
# 2024-05    14
# 2024-06     7
# 2024-07     7
# 2024-08    13
# 2024-09     6
# 2024-10     6
# 2024-11     3
# 2024-12     5
# 2025-01     1
# 2025-02     5
# 2025-03     2
# 2025-04     2
# 2025-05     7
# 2025-06     5
# 2025-07     5
# 2025-08     0
# 2025-09     4
# Name: MENORES_18, dtype: int64

# %%
plt.figure(figsize=(20, 6))
sns.lineplot(x = menores_edad_anio_mes.index, y = menores_edad_anio_mes.values, color = "#E97F4A", marker = "o")

for x, y in zip(menores_edad_anio_mes.index, menores_edad_anio_mes.values):
    plt.text(x, y, str(int(y)), ha = "center", fontsize = 8)

plt.title("Menores de edad víctimas del delito de trata de personas desde Enero del 2017 hasta Diciembre del 2025")
plt.xlabel("Año_Mes")
plt.ylabel("Casos")
plt.grid()
plt.xticks(rotation = 90)
plt.tight_layout()
plt.savefig("../reports/imagenes/Menores_de_edad_víctimas_del_delito_de_trata_de_personas_por_año_mes.png")
plt.show()
